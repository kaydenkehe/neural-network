# %% [markdown]
# ## TensorFlow Comparison
#
# This has exactly the same setup and model as `train.ipynb`, using TensorFlow instead of sandbox for comparison.<br>
# As far as I can tell, this and sandbox appear to have roughly the same performance.

# %%
from h5py import File
import numpy as np
import tensorflow as tf

# %%
# Load data
train_dataset = File('dataset\\train_catvnoncat.h5', 'r')
train_x = np.array(train_dataset['train_set_x'][:]) # Train set features
train_y = np.array(train_dataset['train_set_y'][:]) # Train set labels

test_dataset = File('dataset\\test_catvnoncat.h5', 'r')
test_x = np.array(test_dataset['test_set_x'][:]) # Test set features
test_y = np.array(test_dataset['test_set_y'][:]) # Test set labels

train_y = train_y.reshape((train_y.shape[0], 1))
test_y = test_y.reshape((test_y.shape[0], 1))

# Flatten and normalize
train_x = train_x.reshape(train_x.shape[0], -1) / 255
test_x = test_x.reshape(test_x.shape[0], -1) / 255

# %%
# Create model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(20, activation='relu', input_shape=(train_x.shape[1],)),
    tf.keras.layers.Dense(7, activation='relu'),
    tf.keras.layers.Dense(5, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train model
model.fit(train_x, train_y, batch_size=64, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 5ms/step - loss: 0.8537 - accuracy: 0.4641
# Epoch 2/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6831 - accuracy: 0.5694
# Epoch 3/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6954 - accuracy: 0.6555
# Epoch 4/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6241 - accuracy: 0.6459
# Epoch 5/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6126 - accuracy: 0.6699
# Epoch 6/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5995 - accuracy: 0.6746
# Epoch 7/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5844 - accuracy: 0.7129
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5839 - accuracy: 0.6699
# Epoch 9/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5513 - accuracy: 0.7177
# Epoch 10/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6083 - accuracy: 0.6842
# Epoch 11/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5906 - accuracy: 0.6651
# Epoch 12/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5490 - accuracy: 0.7368
# Epoch 13/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5198 - accuracy: 0.7129
# Epoch 14/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5250 - accuracy: 0.7081
# Epoch 15/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5505 - accuracy: 0.7464
# Epoch 16/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7210 - accuracy: 0.6603
# Epoch 17/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5667 - accuracy: 0.7177
# Epoch 18/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5662 - accuracy: 0.7273
# Epoch 19/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6383 - accuracy: 0.6746
# Epoch 20/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5433 - accuracy: 0.7799
# Epoch 21/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5186 - accuracy: 0.7847
# Epoch 22/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7464
# Epoch 23/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4728 - accuracy: 0.8134
# Epoch 24/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4635 - accuracy: 0.8278
# Epoch 25/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4654 - accuracy: 0.8373
# Epoch 26/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4560 - accuracy: 0.7751
# Epoch 27/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4421 - accuracy: 0.8230
# Epoch 28/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4330 - accuracy: 0.7943
# Epoch 29/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4123 - accuracy: 0.8565
# Epoch 30/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4315 - accuracy: 0.7847
# Epoch 31/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4391 - accuracy: 0.7895
# Epoch 32/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4072 - accuracy: 0.8230
# Epoch 33/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3715 - accuracy: 0.8708
# Epoch 34/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3554 - accuracy: 0.8708
# Epoch 35/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3403 - accuracy: 0.8852
# Epoch 36/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3362 - accuracy: 0.8900
# Epoch 37/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3906 - accuracy: 0.8134
# Epoch 38/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3688 - accuracy: 0.8469
# Epoch 39/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4149 - accuracy: 0.8038
# Epoch 40/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4438 - accuracy: 0.7751
# Epoch 41/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3689 - accuracy: 0.8469
# Epoch 42/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3303 - accuracy: 0.8804
# Epoch 43/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2893 - accuracy: 0.8947
# Epoch 44/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2913 - accuracy: 0.8995
# Epoch 45/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3075 - accuracy: 0.8756
# Epoch 46/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3201 - accuracy: 0.8756
# Epoch 47/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3291 - accuracy: 0.8756
# Epoch 48/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3642 - accuracy: 0.8373
# Epoch 49/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3019 - accuracy: 0.8852
# Epoch 50/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3851 - accuracy: 0.8134
# Epoch 51/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3002 - accuracy: 0.9091
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2465 - accuracy: 0.9187
# Epoch 53/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2620 - accuracy: 0.9043
# Epoch 54/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2704 - accuracy: 0.9139
# Epoch 55/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2601 - accuracy: 0.8995
# Epoch 56/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2701 - accuracy: 0.9091
# Epoch 57/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3344 - accuracy: 0.8182
# Epoch 58/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3000 - accuracy: 0.8947
# Epoch 59/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3263 - accuracy: 0.8612
# Epoch 60/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2358 - accuracy: 0.9043
# Epoch 61/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2140 - accuracy: 0.9522
# Epoch 62/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2279 - accuracy: 0.9474
# Epoch 63/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2162 - accuracy: 0.9426
# Epoch 64/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2035 - accuracy: 0.9522
# Epoch 65/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1996 - accuracy: 0.9569
# Epoch 66/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1899 - accuracy: 0.9713
# Epoch 67/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1851 - accuracy: 0.9761
# Epoch 68/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2090 - accuracy: 0.9474
# Epoch 69/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2744 - accuracy: 0.8756
# Epoch 70/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2402 - accuracy: 0.9043
# Epoch 71/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2102 - accuracy: 0.9426
# Epoch 72/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2190 - accuracy: 0.9282
# Epoch 73/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1882 - accuracy: 0.9569
# Epoch 74/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2042 - accuracy: 0.9234
# Epoch 75/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2122 - accuracy: 0.9330
# Epoch 76/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2101 - accuracy: 0.9282
# Epoch 77/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1830 - accuracy: 0.9569
# Epoch 78/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1655 - accuracy: 0.9761
# Epoch 79/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1634 - accuracy: 0.9569
# Epoch 80/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1649 - accuracy: 0.9761
# Epoch 81/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1564 - accuracy: 0.9617
# Epoch 82/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1476 - accuracy: 0.9713
# Epoch 83/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1407 - accuracy: 0.9617
# Epoch 84/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1378 - accuracy: 0.9713
# Epoch 85/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1499 - accuracy: 0.9761
# Epoch 86/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1791 - accuracy: 0.9378
# Epoch 87/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1466 - accuracy: 0.9665
# Epoch 88/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1581 - accuracy: 0.9522
# Epoch 89/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1415 - accuracy: 0.9665
# Epoch 90/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1237 - accuracy: 0.9761
# Epoch 91/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1286 - accuracy: 0.9761
# Epoch 92/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1372 - accuracy: 0.9665
# Epoch 93/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1222 - accuracy: 0.9761
# Epoch 94/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1242 - accuracy: 0.9809
# Epoch 95/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1680 - accuracy: 0.9426
# Epoch 96/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1470 - accuracy: 0.9569
# Epoch 97/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1211 - accuracy: 0.9809
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2111 - accuracy: 0.9234
# Epoch 99/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1876 - accuracy: 0.9234
# Epoch 100/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1349 - accuracy: 0.9713

# %%
# Print model summary
model.summary()

# Evaluate model
print('\nTraining accuracy:', model.evaluate(train_x, train_y, verbose=0)[1])
print('Testing accuracy:', model.evaluate(test_x, test_y, verbose=0)[1])
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_56 (Dense)            (None, 20)                245780
#
#  dense_57 (Dense)            (None, 7)                 147
#
#  dense_58 (Dense)            (None, 5)                 40
#
#  dense_59 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 245973 (960.83 KB)
# Trainable params: 245973 (960.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Training accuracy: 0.9856459498405457
# Testing accuracy: 0.7200000286102295
